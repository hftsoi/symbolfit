# %% [markdown]
# # Fit toy dataset 1 (1D)

# %%
from symbolfit.symbolfit import *
model = SymbolFit()

dataset = importlib.import_module('examples.toy_dataset_1.dataset')
pysr_config = importlib.import_module('examples.toy_dataset_1.pysr_config')

model.fit(dataset=(dataset.x, dataset.y, dataset.y_up, dataset.y_down),
          bin_widths_1d = dataset.bin_widths_1d,
          pysr_config = pysr_config,
          output_dir = 'examples/toy_dataset_1/run',
          input_rescale = True,
          scale_y_by = 'mean',
          max_stderr = 40,
          loss_weights = None,
          fit_y_unc = True,
          plot_logy = False,
          plot_logx = False
         )
# Out:
# Welcome to JupyROOT 6.30/02
# Compiling Julia backend...
#
# Expressions evaluated per second: 4.010e+05
# Head worker occupation: 20.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.
# Progress: 926 / 3000 total iterations (30.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.639e-01  1.594e+01  y = 0.20652
# 4           1.507e-01  2.791e-02  y = (gauss(x₀) * 0.32227)
# 5           1.498e-01  6.150e-03  y = (exp(-0.98761) * gauss(x₀))
# 6           1.498e-01  2.188e-05  y = ((0.25597 * gauss(x₀)) * 1.4401)
# 8           1.316e-01  6.458e-02  y = ((x₀ + x₀) * gauss(x₀ * -1.8766))
# 9           9.128e-02  3.660e-01  y = ((x₀ * exp(1.6088)) * gauss(x₀ * 2.2836))
# 10          6.813e-02  2.925e-01  y = ((3.0286 * (x₀ * 2.639)) * gauss(x₀ * 2.639))
# 12          3.557e-02  3.250e-01  y = (((x₀ * 2.6156) * gauss(x₀ + (x₀ * 2.6156))) * 7.714)
# 13          3.068e-02  1.477e-01  y = ((tanh(x₀ * 6.6874) * gauss((x₀ + 0.52804) + x₀)) * 6.6874...
#                                   )
# 15          2.970e-02  1.635e-02  y = ((tanh(x₀ * (6.6874 + -0.95194)) * gauss((x₀ + 0.52804) + ...
#                                   x₀)) * 6.6874)
# 17          2.550e-02  7.619e-02  y = (((tanh(x₀ * (1.0131 + 2.1048)) * gauss((x₀ * 2.1048) + x₀...
#                                   )) * 6.6874) + 0.088334)
# 18          2.322e-02  9.384e-02  y = ((((x₀ + (x₀ + x₀)) * gauss((x₀ + (x₀ + -0.10692)) * -2.24...
#                                   29)) * 7.714) + 0.10934)
# 19          2.271e-02  2.217e-02  y = (((tanh((x₀ + x₀) + x₀) * gauss(0.37386 + ((x₀ + x₀) * -2....
#                                   2429))) * 7.714) + 0.10934)
# 21          2.239e-02  7.011e-03  y = ((((((x₀ + -0.01655) + tanh(x₀)) + x₀) * gauss((x₀ + (x₀ +...
#                                    -0.10692)) * -2.2429)) * 7.714) + 0.10934)
# 22          2.236e-02  1.149e-03  y = (((tanh((x₀ + x₀) + (x₀ * 0.57008)) * gauss(0.37386 + ((x₀...
#                                    + x₀) * -2.2429))) * 7.714) + exp(-2.1509))
# 23          2.206e-02  1.355e-02  y = (((tanh((x₀ + x₀) + (x₀ * 0.57008)) * gauss(0.37386 + ((x₀...
#                                    + x₀) * -2.2429))) * (7.714 + 0.62383)) + 0.10934)
# 24          2.177e-02  1.363e-02  y = (((exp(1.6383) * gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (1....
#                                   4959 + 2.2836))) + (x₀ + x₀)) * gauss(x₀ * 2.2836))
# 25          8.723e-03  9.144e-01  y = (((exp(1.4959) * gauss(((x₀ + x₀) + (-0.5102 + x₀)) * (2.2...
#                                   836 + 1.7008))) + (x₀ * exp(1.4959))) * gauss(x₀ * 2.2836))
# 26          5.466e-03  4.674e-01  y = (((exp(1.5161) * gauss(((x₀ + x₀) + (-0.53311 + x₀)) * (2....
#                                   2836 + 1.5764))) + (tanh(x₀) * exp(1.5764))) * gauss(x₀ * 2.28...
#                                   36))
# 27          4.805e-03  1.288e-01  y = (((exp(1.4959) * gauss((((x₀ + x₀) + (-0.5102 + x₀)) * (1....
#                                   4959 + 2.2836)) + -0.16422)) + (x₀ * exp(1.4959))) * gauss(x₀ ...
#                                   * 2.2836))
# 29          4.745e-03  6.252e-03  y = (((exp(1.4959) * gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (1....
#                                   4959 + 2.2836))) + ((exp(1.1115 + 0.17728) * x₀) + x₀)) * gaus...
#                                   s(x₀ * 2.2836))
# 30          4.381e-03  7.997e-02  y = (((exp(1.4959) * gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (1....
#                                   4959 + 2.2836))) + ((exp(1.1115) * x₀) + tanh(x₀ + x₀))) * gau...
#                                   ss(x₀ * 2.2836))
# 31          4.297e-03  1.936e-02  y = (((exp(1.4959) * gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (1....
#                                   4959 + 2.2836))) + ((tanh(x₀ + x₀) + (x₀ * 1.5118)) * 1.4959))...
#                                    * gauss(x₀ * 2.2836))
# 32          4.295e-03  4.715e-04  y = (((((exp(1.4959) * gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (...
#                                   1.4959 + 2.2836))) + tanh(x₀)) + (x₀ + x₀)) + tanh(x₀ * 2.2836...
#                                   )) * gauss(x₀ * 2.2836))
# 33          2.828e-03  4.179e-01  y = (((((2.2836 + 2.2836) * gauss((((x₀ + x₀) + -0.5102) * (2....
#                                   2836 + 2.2836)) + (x₀ * (2.639 + 0.67105)))) + (3.0286 * (x₀ +...
#                                    x₀))) * gauss(x₀ * 2.639)) + 0.052091)
# 35          2.364e-03  8.962e-02  y = ((((((2.2836 + 2.2836) * gauss(((((x₀ + x₀) + -0.5102) * (...
#                                   2.2836 + 2.2836)) + x₀) + (x₀ * 2.639))) + (3.0286 * (x₀ + x₀)...
#                                   )) + x₀) * gauss(x₀ * 2.639)) + 0.052091)
# 36          2.170e-03  8.557e-02  y = ((((((2.2836 + 2.2836) * gauss(((((x₀ + x₀) + -0.5102) * (...
#                                   2.2836 + 2.2836)) + x₀) + (x₀ * 2.639))) + (3.0286 * (tanh(x₀)...
#                                    + x₀))) + x₀) * gauss(x₀ * 2.639)) + 0.052091)
# 37          2.081e-03  4.177e-02  y = ((((((2.2836 + 2.2836) * gauss(((((x₀ + x₀) + -0.5102) * (...
#                                   2.2836 + 2.2836)) + x₀) + (x₀ * 2.639))) + (3.0286 * (tanh(x₀)...
#                                    + tanh(x₀)))) + x₀) * gauss(x₀ * 2.639)) + 0.052091)
# 38          2.075e-03  3.002e-03  y = ((((((2.2836 + 2.2836) * gauss(((((x₀ + x₀) + -0.5102) * (...
#                                   2.2836 + 2.2836)) + x₀) + (x₀ * 2.639))) + (3.0286 * (tanh(x₀)...
#                                    + tanh(x₀)))) + tanh(x₀)) * gauss(x₀ * 2.639)) + 0.052091)
# 39          1.658e-03  2.245e-01  y = ((((((2.2836 + 2.2836) * gauss(((((((x₀ + x₀) + -0.5102) *...
#                                    (2.2836 + 2.639)) + x₀) + x₀) + x₀) + x₀)) + (exp(1.2896) * t...
#                                   anh(x₀ + x₀))) + x₀) * gauss(x₀ * 2.639)) + 0.052091)
# 41          1.503e-03  4.884e-02  y = ((((((3.0286 + exp(x₀)) * gauss(((((x₀ + x₀) + -0.5102) * ...
#                                   (2.5451 + 2.639)) + (x₀ * (3.0286 + 0.32725))) + x₀)) + (3.028...
#                                   6 * tanh((x₀ + x₀) + x₀))) + x₀) * gauss(x₀ * 2.639)) + 0.0520...
#                                   91)
# 42          1.482e-03  1.422e-02  y = (((((3.0286 + gauss(x₀)) * gauss((((((x₀ + x₀) + -0.5102) ...
#                                   * (2.5451 + 2.5451)) + x₀) + 0.041) + (x₀ * 2.639))) + (3.0286...
#                                    * tanh((x₀ * 2.639) + x₀))) * (gauss(x₀ * 2.639) + tanh(0.013...
#                                   627))) + 0.052091)
# 43          1.143e-03  2.600e-01  y = (((((3.0286 + exp(x₀)) * gauss((((((x₀ + x₀) + -0.5102) * ...
#                                   ((2.639 + 2.5451) + x₀)) + x₀) + x₀) + (x₀ * 2.639))) + (3.028...
#                                   6 * tanh((x₀ * 2.639) + x₀))) * (gauss(x₀ * 2.639) + 0.013627)...
#                                   ) + 0.052091)
# 44          1.142e-03  5.795e-04  y = (((((3.0286 + exp(x₀)) * gauss((((((x₀ + x₀) + -0.5102) * ...
#                                   ((2.639 + 2.5451) + x₀)) + x₀) + x₀) + (x₀ * 2.639))) + (3.028...
#                                   6 * tanh((x₀ * 2.639) + x₀))) * (gauss(x₀ * 2.639) + 0.013627)...
#                                   ) + tanh(0.052091))
# 45          1.130e-03  1.030e-02  y = (((((3.0286 + exp(x₀)) * gauss((((((x₀ + x₀) + -0.5102) * ...
#                                   ((2.639 + 2.5451) + (x₀ + x₀))) + x₀) + x₀) + (x₀ * 2.639))) +...
#                                    (3.0286 * tanh((x₀ * 2.639) + x₀))) * (gauss(x₀ * 2.639) + 0....
#                                   013627)) + 0.052091)
# 46          1.130e-03  5.366e-04  y = (((((3.0286 + exp(x₀)) * gauss((((((x₀ + x₀) + -0.5102) * ...
#                                   ((2.639 + 2.5451) + (x₀ + x₀))) + x₀) + x₀) + (x₀ * 2.639))) +...
#                                    (3.0286 * tanh((x₀ * 2.639) + x₀))) * (gauss(x₀ * 2.639) + 0....
#                                   013627)) + tanh(0.052091))
# 47          1.042e-03  8.065e-02  y = (((((3.0286 + (exp(x₀) + x₀)) * gauss((((((x₀ + x₀) + -0.5...
#                                   102) * ((2.639 + 2.5451) + (x₀ + 0.13735))) + x₀) + x₀) + (x₀ ...
#                                   * 2.639))) + (3.0286 * tanh((x₀ * 2.639) + x₀))) * (gauss(x₀ *...
#                                    2.639) + 0.013627)) + 0.052091)
# 49          1.042e-03  2.709e-04  y = (((((3.0286 + (exp(x₀ * 0.60021) + x₀)) * gauss((((((x₀ + ...
#                                   x₀) + -0.5102) * ((2.639 + 2.5451) + (x₀ + 0.13735))) + x₀) + ...
#                                   x₀) + (x₀ * 2.639))) + (3.0286 * tanh((x₀ * 2.639) + x₀))) * (...
#                                   gauss(x₀ * 2.639) + 0.013627)) + 0.052091)
# 50          9.413e-04  1.013e-01  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   2.639 + 2.639) + 0.29088)) + ((x₀ * 2.639) + (x₀ * (x₀ + -0.04...
#                                   4165)))) + x₀) + x₀)) + (3.0286 * tanh(x₀ * (((1.0314 + 2.5949...
#                                   ) + x₀) + x₀)))) * gauss(x₀ * 2.639)) + 0.068548)
# 53          8.855e-04  2.040e-02  y = ((((((3.0286 + x₀) + 1.191) * gauss((((((x₀ + x₀) + -0.510...
#                                   2) * ((2.639 + 2.639) + 0.29088)) + ((x₀ * 2.639) + (x₀ * (x₀ ...
#                                   + -0.044165)))) + x₀) + x₀)) + (3.0286 * tanh(x₀ * (((1.0314 +...
#                                    2.5949) + x₀) + x₀)))) * gauss(x₀ * 2.639)) + tanh(0.068548))
# 57          8.731e-04  3.515e-03  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   2.639 + 2.639) + 0.29088)) + ((x₀ * 2.639) + (x₀ * (((0.29025 ...
#                                   + -0.3744) + x₀) + -0.044165)))) + x₀) + x₀)) + (3.0286 * tanh...
#                                   (x₀ * (((1.0314 + 2.639) + x₀) + (x₀ + x₀))))) * gauss(x₀ * 2....
#                                   639)) + tanh(0.068548))
# 59          8.535e-04  1.134e-02  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   (2.639 + 2.639) + 0.29088) + 0.10736)) + ((x₀ * 2.639) + (((0....
#                                   29025 + -0.3744) + x₀) + -0.044165))) + x₀) + x₀)) + (3.0286 *...
#                                    tanh(x₀ * (((((1.0314 + 2.639) + x₀) + x₀) + x₀) + x₀)))) * g...
#                                   auss(x₀ * 2.639)) + tanh(0.068548))
# 61          8.108e-04  2.566e-02  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   (2.639 + 2.639) + 0.29088) + 0.10736)) + ((x₀ * 2.639) + (((0....
#                                   29025 + -0.3744) + x₀) + -0.044165))) + x₀) + x₀)) + (3.0286 *...
#                                    tanh(x₀ * (((((1.0314 + 2.639) + x₀) + (x₀ + x₀)) + x₀) + x₀)...
#                                   ))) * gauss(x₀ * 2.639)) + tanh(0.068548))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.430e+05
# Head worker occupation: 14.4%
# Progress: 2059 / 3000 total iterations (68.633%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.639e-01  1.594e+01  y = 0.20651
# 4           1.507e-01  2.791e-02  y = (gauss(x₀) * 0.32227)
# 5           1.498e-01  6.150e-03  y = (exp(-0.98761) * gauss(x₀))
# 6           1.484e-01  9.583e-03  y = (gauss(x₀ * x₀) * 0.32227)
# 8           8.732e-02  2.650e-01  y = ((x₀ * gauss(x₀ * 3.1163)) * 7.714)
# 9           3.253e-02  9.872e-01  y = ((exp(3.1163) * x₀) * gauss(x₀ * -3.5232))
# 10          3.233e-02  6.282e-03  y = ((exp(3.1163) * tanh(x₀)) * gauss(x₀ * -3.5232))
# 11          2.378e-02  3.070e-01  y = (((exp(3.1163) * x₀) * gauss(x₀ * 3.7642)) + 0.097882)
# 12          2.359e-02  8.308e-03  y = (((tanh(x₀) * exp(3.1163)) * gauss(x₀ * -3.6345)) + 0.1045...
#                                   8)
# 13          2.266e-02  3.989e-02  y = (((exp(3.187) * x��) * gauss(x₀ * (-4.1721 + x₀))) + 0.0911...
#                                   4)
# 15          2.224e-02  9.423e-03  y = ((((exp(3.187) * x₀) + -0.037394) * gauss(x₀ * (-4.1721 + ...
#                                   x₀))) + 0.09114)
# 17          2.187e-02  8.451e-03  y = (((exp(3.187) * x₀) * gauss((x₀ * (-4.1721 + (x₀ * x₀))) +...
#                                    0.097108)) + 0.087912)
# 19          2.096e-02  2.124e-02  y = ((((exp(3.1163) * x₀) * gauss(x₀ * 3.7642)) + (x₀ * gauss(...
#                                   x₀ * -1.2463))) * gauss(x₀))
# 20          2.093e-02  1.477e-03  y = ((((exp(3.1163) * x₀) * gauss(x₀ * 3.7642)) + (tanh(x₀) * ...
#                                   gauss(x₀ * -1.2463))) * gauss(x₀))
# 21          2.056e-02  1.768e-02  y = (((((exp(3.1163) * x₀) + x₀) * gauss(x₀ * 3.7642)) + (x₀ *...
#                                    gauss(x₀))) * gauss(x₀ * 1.2434))
# 22          4.718e-03  1.472e+00  y = ((exp(1.5522) * (gauss((((x₀ + x₀) + x₀) + -0.55181) * (1....
#                                   933 + 1.933)) + x₀)) * gauss(x₀ * 2.2852))
# 23          4.626e-03  1.977e-02  y = ((exp(1.5522) * (gauss((((x₀ + x₀) + x₀) + -0.55181) * (1....
#                                   933 + 1.933)) + tanh(x₀))) * gauss(x₀ * 2.2852))
# 24          4.382e-03  5.420e-02  y = ((exp(1.4959) * (gauss(((x₀ + x₀) + (-0.55993 + x₀)) * (2....
#                                   2852 + 1.5174)) + (x₀ * 1.2396))) * gauss(x₀ * -2.4282))
# 26          3.638e-03  9.305e-02  y = (((exp(1.4959 + 0.062656) * (gauss(((x₀ + x₀) + (-0.55993 ...
#                                   + x₀)) * (1.6736 + 2.2852)) + x₀)) * gauss(x₀ * -2.4282)) + 0....
#                                   038538)
# 27          3.612e-03  7.221e-03  y = ((((exp(1.4959) + tanh(0.31536)) * (gauss(((x₀ + x₀) + (-0...
#                                   .55993 + x₀)) * (1.6736 + 2.2852)) + x₀)) * gauss(x₀ * -2.4282...
#                                   )) + 0.038538)
# 28          1.524e-03  8.625e-01  y = (((exp(1.5522) * ((gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (...
#                                   2.4456 + 2.4456)) + x₀) + x₀)) * gauss((x₀ * 1.2142) * 2.4456)...
#                                   ) + 0.065692)
# 29          1.438e-03  5.806e-02  y = (((exp(1.5522) * (gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (2...
#                                   .4456 + 2.4456)) + tanh(x₀ + x₀))) * gauss((x₀ * 1.2142) * 2.2...
#                                   852)) + 0.065692)
# 31          1.294e-03  5.295e-02  y = ((((exp(1.5522) * (gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (...
#                                   2.4456 + 2.4456)) + tanh(x₀ + x₀))) * gauss((x₀ * 1.2142) * 2....
#                                   2852)) + 0.017021) + 0.065692)
# 33          1.257e-03  1.440e-02  y = ((((exp(1.5522) * (gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (...
#                                   2.4456 + 2.4456)) + tanh(x₀ + x₀))) * gauss((x₀ * 1.2142) * 2....
#                                   2852)) + (0.017021 * x₀)) + 0.065692)
# 34          1.256e-03  8.653e-04  y = ((((exp(1.5522) * (gauss(((x₀ + x₀) + (-0.55181 + x₀)) * (...
#                                   2.4456 + 2.4456)) + tanh(x₀ + x₀))) * gauss((x₀ * 1.2142) * 2....
#                                   2852)) + (0.017021 * tanh(x₀))) + 0.065692)
# 35          1.236e-03  1.645e-02  y = (((exp(1.5522) * (gauss((((x₀ + x₀) + (-0.55181 + x₀)) * (...
#                                   2.4456 + 2.4456)) + (0.95326 + -0.91269)) + tanh(x₀ + x₀))) * ...
#                                   gauss((x₀ * 1.2142) * 2.2852)) + (0.065692 * 1.0652))
# 37          1.176e-03  2.461e-02  y = ((((exp(1.5522) * (gauss((((x₀ + x₀) + (-0.55181 + x₀)) * ...
#                                   ((1.2142 + 2.2836) + 1.5522)) + (x₀ * 0.34431)) + tanh(x₀ + x₀...
#                                   ))) * gauss((x₀ * 1.2142) * 2.2852)) + 0.017021) + 0.065692)
# 38          1.176e-03  6.437e-06  y = ((((exp(1.5522) * (gauss((((x₀ + x₀) + (-0.55181 + x₀)) * ...
#                                   ((1.2142 + 2.2836) + 1.5522)) + (x₀ * 0.34431)) + tanh(x₀ + x₀...
#                                   ))) * gauss((x₀ * 1.2142) * 2.2852)) + tanh(0.017021)) + 0.065...
#                                   692)
# 39          1.176e-03  3.692e-04  y = ((((exp(1.5522) * (gauss((((x₀ + x₀) + (-0.55181 + x₀)) * ...
#                                   ((1.2142 + 2.2836) + 1.5522)) + (x₀ * 0.34431)) + tanh(x₀ + x₀...
#                                   ))) * gauss((x₀ * 1.2142) * 2.2852)) + tanh(0.017021)) + tanh(...
#                                   0.065692))
# 40          9.531e-04  2.100e-01  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   2.639 + 2.639) + 0.29088)) + (x₀ * 2.639)) + x₀) + x₀)) + (3.0...
#                                   286 * tanh((x₀ * 3.0286) + x₀))) * gauss(x₀ * 2.639)) + 0.0685...
#                                   48)
# 43          9.199e-04  1.179e-02  y = (((((3.0286 + exp(x₀)) * gauss((((((x₀ + x₀) + -0.5102) * ...
#                                   ((2.639 + 2.639) + 0.29088)) + (x₀ * 2.639)) + x₀) + x₀)) + (3...
#                                   .0286 * tanh((x₀ * (3.0286 + x₀)) + x₀))) * gauss(x₀ * 2.639))...
#                                    + 0.068548)
# 44          9.141e-04  6.338e-03  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   2.639 + 2.639) + 0.29088)) + (x₀ * 2.639)) + x₀) + x₀)) + (3.0...
#                                   286 * tanh(((x₀ * 3.0286) + (x₀ * x₀)) + x₀))) * gauss(x₀ * 2....
#                                   639)) + 0.068548)
# 46          8.868e-04  1.515e-02  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   2.639 + 2.639) + 0.29088)) + (x₀ * 2.639)) + x₀) + x₀)) + (3.0...
#                                   286 * tanh(x₀ * ((x₀ + x₀) + (2.5949 + (0.77815 + 0.42097)))))...
#                                   ) * gauss(x₀ * 2.639)) + 0.068548)
# 48          8.586e-04  1.619e-02  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   2.639 + 2.639) + 0.29088)) + (x₀ * (2.639 + 0.14283))) + x₀) +...
#                                    x₀)) + (3.0286 * tanh(x₀ * ((((1.0314 + x₀) + 2.5949) + x₀) +...
#                                    x₀)))) * gauss(x₀ * 2.639)) + 0.068548)
# 50          8.407e-04  1.053e-02  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   2.639 + 2.639) + 0.29088)) + (x₀ * (2.639 + x₀))) + x₀) + x₀))...
#                                    + (3.0286 * tanh(x₀ * ((((1.0314 + x₀) + 2.5949) + x₀) + x₀))...
#                                   )) * gauss(x₀ * 2.639)) + (0.068548 * 1.1723))
# 51          8.327e-04  9.521e-03  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   2.639 + 2.639) + 0.29088)) + (x₀ * (2.5949 + x₀))) + x₀) + x₀)...
#                                   ) + (3.0286 * (tanh(x₀ * (((1.0314 + 2.5949) + x₀) + x₀)) + -0...
#                                   .0040891))) * gauss(x₀ * 2.639)) + (tanh(0.068548) * 1.1723))
# 53          7.742e-04  3.647e-02  y = (((((3.0286 + 1.191) * gauss((((((x₀ + x₀) + -0.5102) * ((...
#                                   2.639 + 2.639) + 0.29088)) + (x₀ * (2.5949 + x₀))) + x₀) + x₀)...
#                                   ) + (3.0286 * (tanh(x₀ * ((((1.0314 + x₀) + 2.5949) + x₀) + x₀...
#                                   )) + -0.0040891))) * gauss(x₀ * 2.639)) + (tanh(0.068548) * 1....
#                                   1723))
# 58          7.505e-04  6.209e-03  y = ((((((3.0286 + x₀) + 1.191) * gauss((((((x₀ + x₀) + -0.510...
#                                   2) * ((2.639 + 2.639) + 0.6163)) + (x₀ * (2.639 + -0.49494))) ...
#                                   + (x₀ + x₀)) + x₀)) + (3.0286 * tanh(x₀ * ((((1.0314 + x₀) + x...
#                                   ₀) + 2.5949) + x₀)))) * gauss(x₀ * 2.639)) + (0.068548 * (tanh...
#                                   (x₀) + gauss(x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# [ Info: Started!
# Checking if pysr_model_temp.pkl exists...
# Loading model from pysr_model_temp.pkl
# Re-fitting candidate 1/51...
# Re-fitting candidate 2/51...DF for bad fits 2/2...
#     -> attempt to decrease NDF for bad fits 1/2...
# Re-fitting candidate 3/51...
#     -> attempt to decrease NDF for bad fits 1/2...
# Re-fitting candidate 4/51...
#     -> attempt to decrease NDF for bad fits 1/2...
# Re-fitting candidate 5/51...
#     -> attempt to decrease NDF for bad fits 1/4...
# Re-fitting candidate 6/51...
#     -> attempt to decrease NDF for bad fits 1/4...
# Re-fitting candidate 7/51...
#     -> attempt to decrease NDF for bad fits 1/4...
# Re-fitting candidate 8/51...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 9/51...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 10/51...
#     -> attempt to decrease NDF for bad fits 3/8...
# Re-fitting candidate 11/51...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 12/51...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 13/51...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 14/51...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 15/51...
#     -> attempt to decrease NDF for bad fits 1/16...
# Re-fitting candidate 16/51...
#     -> attempt to decrease NDF for bad fits 2/16...
# Re-fitting candidate 17/51...
#     -> attempt to decrease NDF for bad fits 1/16...
# Re-fitting candidate 18/51...
#     -> attempt to decrease NDF for bad fits 1/16...
# Re-fitting candidate 19/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 20/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 21/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 22/51...
#     -> attempt to decrease NDF for bad fits 1/64...
# Re-fitting candidate 23/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 24/51...
#     -> attempt to decrease NDF for bad fits 1/64...
# Re-fitting candidate 25/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 26/51...
#     -> attempt to decrease NDF for bad fits 1/64...
# Re-fitting candidate 27/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 28/51...
#     -> attempt to decrease NDF for bad fits 1/64...
# Re-fitting candidate 29/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 30/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 31/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 32/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 33/51...
#     -> attempt to decrease NDF for bad fits 1/64...
# Re-fitting candidate 34/51...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 35/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 36/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 37/51...
#     -> attempt to decrease NDF for bad fits 3/256...
# Re-fitting candidate 38/51...
#     -> attempt to decrease NDF for bad fits 3/256...
# Re-fitting candidate 39/51...
#     -> attempt to decrease NDF for bad fits 20/512...
# Re-fitting candidate 40/51...
#     -> attempt to decrease NDF for bad fits 20/512...
# Re-fitting candidate 41/51...
#     -> attempt to decrease NDF for bad fits 20/512...
# Re-fitting candidate 42/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 43/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 44/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 45/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 46/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 47/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 48/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 49/51...
#     -> attempt to decrease NDF for bad fits 1/128...
# Re-fitting candidate 50/51...
#     -> attempt to decrease NDF for bad fits 4/256...
# Re-fitting candidate 51/51...
#     -> attempt to decrease NDF for bad fits 20/512...
# Plotting candidate functions 51/51 to examples/toy_dataset_1/run/candidates.pdf...
# Plotting correlation matrices 51/51 to examples/toy_dataset_1/run/candidates_correlation.pdf...
# Plotting goodness-of-fit to examples/toy_dataset_1/run/candidates_gof.pdf...

# %% [markdown]
# # Fit toy dataset 3b (2D)

# %%
from symbolfit.symbolfit import *
model = SymbolFit()

dataset = importlib.import_module('examples.toy_dataset_3.dataset_3b')
pysr_config = importlib.import_module('examples.toy_dataset_3.pysr_config')

model.fit(dataset=(dataset.x, dataset.y, dataset.y_up, dataset.y_down),
          bin_edges_2d = dataset.bin_edges_2d,
          pysr_config = pysr_config,
          output_dir = 'examples/toy_dataset_3/run_b',
          input_rescale = False,
          scale_y_by = None,
          max_stderr = 40,
          fit_y_unc = True,
          plot_logy = False,
          plot_logx = False
         )
# Out:
# Welcome to JupyROOT 6.30/02
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 3.420e+05
# Head worker occupation: 11.2%
# Progress: 765 / 3000 total iterations (25.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.351e+00  1.594e+01  y = 3.7671
# 2           3.449e+00  9.973e-01  y = exp(1.7609)
# 4           2.998e+00  7.009e-02  y = (exp(1.7609) + x₁)
# 5           2.890e+00  3.656e-02  y = ((x₁ + x₁) + 5.2733)
# 9           2.857e+00  2.883e-03  y = ((exp(1.7609) + x₁) + (tanh(x₀) * -0.54711))
# 10          2.653e+00  7.435e-02  y = (((x₁ + exp(1.7609)) + x₁) + (x₀ * -0.54711))
# 11          2.635e+00  6.542e-03  y = (((x₁ + exp(1.7609)) + tanh(x₁)) + (x₀ * -0.54711))
# 12          2.588e+00  1.796e-02  y = ((gauss(x₀) + (x₁ + exp(0.81704))) + (x₁ + exp(0.81704)))
# 13          2.282e+00  1.260e-01  y = (exp(1.7044) + (gauss(((x₀ * 1.3557) + x₀) * x₀) + x₁))
# 14          1.749e+00  2.661e-01  y = (4.6829 + (gauss(x₁ + ((x₀ * x₀) * -3.0046)) * (4.6829 + x...
#                                   ₁)))
# 15          9.268e-01  6.349e-01  y = ((exp(x₀) * 1.9235) + (gauss(x₁ + ((x₀ * x₀) * -3.0423)) *...
#                                    6.2685))
# 17          6.033e-01  2.147e-01  y = ((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9088)) * 6.10...
#                                   43)) + 2.1254)
# 18          5.795e-01  4.031e-02  y = ((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9267)) * 6.38...
#                                   84)) + exp(x₁))
# 19          4.737e-01  2.015e-01  y = ((exp(x₀ * x₀) + (1.9235 + x₁)) + (gauss(x₁ + ((x₀ * x₀) *...
#                                    -3.0423)) * 6.1521))
# 20          4.238e-01  1.112e-01  y = (((exp(x₀ * x₀) + x₁) + (gauss(x₁ + ((x₀ * x₀) * -2.9088))...
#                                    * 6.1043)) + exp(0.44096))
# 21          4.138e-01  2.404e-02  y = (((exp(x₀ * x₀) + 1.2347) + (gauss(x₁ + ((x₀ * x₀) * -3.04...
#                                   23)) * 6.1521)) + (x₁ + x₁))
# 22          3.808e-01  8.302e-02  y = ((exp(x₀ * x₀) + (((gauss(x₁ + ((x₀ * x₀) * -2.9241)) * 6....
#                                   0467) + x₁) + tanh(x₁))) + 1.2943)
# 23          3.657e-01  4.042e-02  y = ((exp(x₀ * x₀) + (((gauss(x₁ + ((x₀ * x₀) * -2.9241)) * 6....
#                                   0467) + tanh(x₁)) + tanh(x₁))) + 1.333)
# 25          3.605e-01  7.159e-03  y = ((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9241)) * 6.04...
#                                   67)) + ((tanh(x₁ + x₁) + x₁) + exp(0.052731)))
# 26          3.459e-01  4.129e-02  y = ((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9241)) * 6.04...
#                                   67)) + ((tanh(x₁ + x₁) + tanh(x₁)) + exp(0.052731)))
# 27          3.367e-01  2.695e-02  y = (((((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5...
#                                   .4848)) + x₁) + tanh(5.4848 * x₁)) + gauss(x₀)) + 0.55808)
# 28          3.266e-01  3.051e-02  y = (((((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5...
#                                   .4848)) + x₁) + tanh(5.4848 * x₁)) + gauss(x₀)) + tanh(0.55808...
#                                   ))
# 29          3.240e-01  8.161e-03  y = (((((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5...
#                                   .4848)) + tanh(x₁)) + tanh(5.4848 * x₁)) + gauss(x₀)) + tanh(0...
#                                   .55808))
# 31          3.239e-01  1.429e-04  y = (((((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5...
#                                   .4848)) + tanh(x₁ + -0.0021514)) + tanh(5.4848 * x₁)) + gauss(...
#                                   x₀)) + tanh(0.55808))
# 32          3.207e-01  9.716e-03  y = (((((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5...
#                                   .4848)) + x₁) + tanh(((5.4848 + -1.7258) + 0.052465) * x₁)) + ...
#                                   gauss(x₀)) + tanh(0.55808))
# 33          3.154e-01  1.675e-02  y = ((((exp(x₀ * (x₀ * 1.0945)) + (gauss(x₁ + ((x₀ * x₀) * -2....
#                                   9541)) * 5.4848)) + tanh(x₁ + (x₁ * 1.6476))) + x₁) + (gauss(x...
#                                   ₀) * (1.2265 + 0.33096)))
# 34          3.096e-01  1.863e-02  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + tanh(x₁))) + 0.49348) + tanh(5.4848 * (x...
#                                   ₁ + -0.025599))) + (gauss(x₀) * 0.95784))
# 35          3.052e-01  1.414e-02  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + tanh(x₁))) + tanh(0.49348)) + tanh(5.484...
#                                   8 * (x₁ + -0.025599))) + (gauss(x₀) * 0.95784))
# 36          3.039e-01  4.520e-03  y = (((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) *...
#                                    -2.9541)) * 5.4848) + tanh(x₁))) + 0.49348) + tanh(5.4848 * (...
#                                   x₁ + -0.025599))) + (gauss(x₀) * 0.95784)) + -0.09594)
# 37          3.015e-01  7.921e-03  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + gauss(x₀)) + (gauss(...
#                                   x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 + tanh(x₁ + x₁...
#                                   ))))) + gauss(x₁ * x₀)) + tanh(x₁))
# 38          2.625e-01  1.382e-01  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + gauss(x₀)) + (gauss(...
#                                   x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 + tanh((x₁ * 2...
#                                   .5861) + x₁))))) + gauss(x��� * x₀)) + x₁)
# 40          2.594e-01  5.999e-03  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + gauss(x₀)) + (gauss(...
#                                   x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 + tanh((x₁ * 2...
#                                   .5861) + (x₁ + x₁)))))) + gauss(x₁ * x₀)) + x₁)
# 41          2.418e-01  7.012e-02  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh(2.0268 * (x₁ + x₁)))...
#                                   ))) + gauss(x₁ * x₀)) + gauss(x₀ * x₀)) + tanh(x₁))
# 43          2.349e-01  1.465e-02  y = ((((exp(x₀ * ((x₀ * 0.96009) + (0.33406 * x₁))) + gauss(x₀...
#                                   )) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 + ...
#                                   tanh((2.0268 + 2.0268) * x₁))))) + gauss((x₁ * x₀) * x₁)) + ta...
#                                   nh(x₁))
# 44          2.217e-01  5.745e-02  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh(2.0268 * (x₁ + x₁)))...
#                                   ))) + gauss(x₁ * ((x₀ + x₀) * x₁))) + gauss(x₀ * x₀)) + x₁)
# 47          2.189e-01  4.296e-03  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh(((x₁ + 2.295) + 1.3539) * x₁))))) + gauss(x₁ * (x₀ * 1....
#                                   5186))) + tanh(x₁ + x₁))
# 49          2.171e-01  4.134e-03  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh(((1.4901 * x₁) + x₁) + (-0.082482 + x₁)))))) + gauss(x₁...
#                                    * (x₀ * 1.5186))) + tanh(x₁ + x₁))
# 51          2.163e-01  1.957e-03  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((x₁ + ((1.4901 * x₁) + x₁)) + (-0.082482 + x₁)))))) + g...
#                                   auss(x₁ * (x₀ * 1.5186))) + tanh(x₁ + x₁))
# 53          2.027e-01  3.234e-02  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((((x₁ + 2.295) + 1.3539) + -1.0373) * ((x₁ + -0.18953) ...
#                                   + x₁)))))) + gauss(x₁ * (x₀ * 1.5186))) + tanh(x₁ + x₁))
# 55          1.956e-01  1.792e-02  y = ((((exp((x₀ * 0.99397) * ((x₀ + (0.40396 * x₁)) + -0.06071...
#                                   1)) + gauss(x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.026...
#                                   8 * (2.0268 + tanh(((2.295 + 1.3539) + x₁) * ((x₁ + -0.18953) ...
#                                   + x₁)))))) + gauss((x₁ * 0.90495) * (x₀ * 1.5186))) + tanh(x₁ ...
#                                   + x₁))
# 57          1.841e-01  3.024e-02  y = ((((exp((x₀ * 0.99397) * ((x₀ + (0.40396 * x₁)) + -0.06071...
#                                   1)) + gauss(x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.026...
#                                   8 * (2.0268 + tanh((((x₁ + 0.96818) + 2.295) + 1.3539) * ((x₁ ...
#                                   + -0.18953) + x₁)))))) + gauss((x₁ * x₁) * (x₀ * 1.5186))) + t...
#                                   anh(x₁ + 0.20062))
# 59          1.837e-01  9.833e-04  y = ((((exp((x₀ * 0.99397) * ((x₀ + (0.40396 * x₁)) + -0.06071...
#                                   1)) + gauss(x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.026...
#                                   8 * (2.0268 + tanh((((x₁ + (0.96818 + x₁)) + 2.295) + 1.3539) ...
#                                   * ((x₁ + -0.18953) + x₁)))))) + gauss((x₁ * x₁) * (x₀ * 1.5186...
#                                   ))) + tanh(x₁ + 0.20062))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.460e+05
# Head worker occupation: 14.4%
# Progress: 1556 / 3000 total iterations (51.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.278e+00  1.594e+01  y = 6.2314
# 4           2.998e+00  2.974e-02  y = (exp(1.7609) + x₁)
# 5           2.890e+00  3.656e-02  y = ((x₁ + x₁) + 5.2733)
# 9           2.857e+00  2.883e-03  y = ((exp(1.7609) + x₁) + (tanh(x₀) * -0.54711))
# 10          2.653e+00  7.435e-02  y = (((x₁ + exp(1.7609)) + x₁) + (x₀ * -0.54711))
# 11          2.635e+00  6.542e-03  y = (((x₁ + exp(1.7609)) + tanh(x₁)) + (x₀ * -0.54711))
# 12          1.822e+00  3.691e-01  y = ((exp(x₀) + (gauss(x₀ + 0.33443) * 6.8232)) + exp(x₁))
# 13          1.784e+00  2.127e-02  y = ((exp(x₀) * 1.9235) + (gauss((x₀ * x₀) * -3.0423) * 6.2685...
#                                   ))
# 14          1.655e+00  7.459e-02  y = ((exp(x₀ * x₀) + (gauss(x₀ + 0.36301) * 6.3884)) + exp(x₁)...
#                                   )
# 15          9.268e-01  5.801e-01  y = ((exp(x₀) * 1.9235) + (gauss(x₁ + ((x₀ * x₀) * -3.0423)) *...
#                                    6.2685))
# 17          6.033e-01  2.147e-01  y = ((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9088)) * 6.10...
#                                   43)) + 2.1254)
# 18          5.443e-01  1.029e-01  y = ((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.765)) * 6.486...
#                                   7)) + exp(x₁))
# 19          4.147e-01  2.718e-01  y = (((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9241)) * 6.0...
#                                   467)) + 1.6496) + x₁)
# 20          4.143e-01  1.049e-03  y = (((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9241)) * 6.0...
#                                   467)) + x₁) + exp(0.51341))
# 21          3.952e-01  4.730e-02  y = (((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9299)) * (5....
#                                   4848 + x₁))) + 1.6787) + x₁)
# 22          3.793e-01  4.094e-02  y = ((((exp(x₀ * x₀) + x₁) + (gauss(x₁ + ((x₀ * x₀) * -2.9241)...
#                                   ) * 6.0467)) + 1.2536) + tanh(x₁))
# 23          3.657e-01  3.655e-02  y = ((exp(x₀ * x₀) + (((gauss(x₁ + ((x₀ * x₀) * -2.9241)) * 6....
#                                   0467) + tanh(x₁)) + tanh(x₁))) + 1.333)
# 24          3.497e-01  4.473e-02  y = (((exp(x₀ * x₀) + x₁) + (gauss(x₁ + ((x₀ * x₀) * -2.9241))...
#                                    * 6.0467)) + (0.66743 + tanh(6.0467 * x₁)))
# 25          3.366e-01  3.823e-02  y = (((exp(x₀ * x₀) + x₁) + (gauss(x₁ + ((x₀ * x₀) * -2.9241))...
#                                    * 6.0467)) + (gauss(0.48112) + tanh(6.0467 * x₁)))
# 27          3.214e-01  2.303e-02  y = ((((exp(x₀ * x₀) + ((gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5...
#                                   .4848) + x₁)) + 0.42541) + tanh(5.4848 * x₁)) + gauss(x₀))
# 28          3.125e-01  2.808e-02  y = ((exp(x₀ * x₀) + (((gauss(x₁ + ((x₀ * x₀) * -2.9241)) * 6....
#                                   0467) + tanh(x₁ * 6.0467)) + tanh(x₁))) + tanh(x��� * 6.0467))
# 29          3.103e-01  7.210e-03  y = (((exp(x₀ * x₀) + ((gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5....
#                                   4848) + (x₁ + 0.52007))) + tanh((5.4848 * x₁) + -0.42909)) + g...
#                                   auss(x₀))
# 30          2.988e-01  3.773e-02  y = ((((exp(x₀ * x₀) + ((gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5...
#                                   .4848) + tanh(x₁))) + 0.61231) + tanh((5.4848 * x₁) + -0.44376...
#                                   )) + gauss(x₀))
# 33          2.983e-01  5.514e-04  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + x₁)) + 0.49348) + tanh(5.4848 * x₁)) + g...
#                                   auss((x₀ + x₁) * x₀))
# 34          2.953e-01  1.027e-02  y = (((exp(x₀ * (x₀ + 0.0059929)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + tanh(x₁ + (-0.069652 + x₁)))) + (tanh(5....
#                                   4848 * x₁) * 1.3581)) + gauss(x₀))
# 35          2.596e-01  1.288e-01  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + x₁)) + 0.49348) + tanh((5.4848 * x₁) + -...
#                                   0.42909)) + gauss(x₀ * (x₀ + x₁)))
# 37          2.457e-01  2.739e-02  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + x₁)) + 0.49348) + tanh((5.4848 * x₁) + -...
#                                   0.42909)) + gauss((x₀ * x₀) * (x₀ + x₁)))
# 39          2.421e-01  7.457e-03  y = ((((exp(x₀ * (x₀ + 0.092003)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + x₁)) + 0.49348) + tanh(((5.4848 * x₁) + ...
#                                   -0.85803) + x₁)) + gauss((x₀ * x₀) * (x₀ + x₁)))
# 40          2.334e-01  3.664e-02  y = ((((exp(x₀ * (x₀ + 0.092003)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + tanh(x₁))) + 0.49348) + tanh(((5.4848 * ...
#                                   x₁) + -0.85803) + x₁)) + gauss((x₀ * x₀) * (x₀ + x₁)))
# 42          2.265e-01  1.502e-02  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh(2.0268 * (x₁ + x₁)))...
#                                   ))) + gauss(x₁ * ((x₀ + x₀) * x₁))) + gauss(x₀)) + x₁)
# 43          2.230e-01  1.535e-02  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh((2.0268 + 1.3662) * ...
#                                   ((x₁ + x₁) + -0.12275)))))) + gauss(x₁ * x₀)) + gauss(x₀)) + t...
#                                   anh(x₁))
# 44          2.217e-01  5.735e-03  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh(2.0268 * (x₁ + x₁)))...
#                                   ))) + gauss(x₁ * ((x₀ + x₀) * x₁))) + gauss(x₀ * x₀)) + x₁)
# 45          2.174e-01  1.965e-02  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh((2.0268 * (x₁ + (x₁ ...
#                                   + x₁))) + -0.50064))))) + gauss(x₀ * x₁)) + gauss(x₀ * x₀)) + ...
#                                   tanh(x₁))
# 47          2.134e-01  9.320e-03  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((1.6781 + 2.0268) * ((x₁ + -0.18953) + x₁)))))) + gauss...
#                                   ((x₁ * x₀) * x₁)) + tanh(x₁))
# 49          2.021e-01  2.726e-02  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((2.295 + 1.3539) * ((x₁ + -0.18953) + x₁)))))) + gauss(...
#                                   (x₁ * x₁) * (x₀ * 1.5186))) + tanh(x₁))
# 50          1.976e-01  2.239e-02  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh((2.0268 * (x₁ + x₁))...
#                                    + ((x₁ + x₁) + -0.50064)))))) + gauss(((x₀ + x₀) * x₁) * x₁))...
#                                    + gauss(x₀ * x₀)) + x₁)
# 51          1.890e-01  4.434e-02  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((2.295 + 1.3539) * ((x₁ + -0.18953) + x₁)))))) + (gauss...
#                                   ((x₁ * x₁) * (x₀ * 1.5186)) * 1.2254)) + tanh(x₁))
# 53          1.869e-01  5.781e-03  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((2.295 + 2.0268) * ((x₁ + -0.18953) + x₁)))))) + gauss(...
#                                   (x₁ * x₁) * (x₀ * (1.5186 + 1.1504)))) + tanh(x₁ + x₁))
# 55          1.828e-01  1.093e-02  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((2.295 + 2.0268) * ((x₁ + -0.18953) + x��)))))) + gauss(...
#                                   ((x₁ + -0.07172) * x₁) * (x₀ * (1.5186 + 0.84545)))) + tanh(x₁...
#                                    + x₁))
# 57          1.800e-01  7.832e-03  y = ((((exp((x₀ * 0.99397) * ((x₀ + (0.40396 * x₁)) + -0.06071...
#                                   1)) + gauss(x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.026...
#                                   8 * (2.0268 + tanh((((1.3539 + 0.96818) + 2.295) + 1.3539) * (...
#                                   (x₁ + -0.18953) + x₁)))))) + (gauss((x₁ * x₁) * (x₀ * 1.5186))...
#                                    * 1.186)) + tanh(x₁))
# 59          1.787e-01  3.698e-03  y = (((((exp((x₀ * 0.99397) * ((x₀ + (0.40396 * x₁)) + -0.0607...
#                                   11)) + gauss(x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.02...
#                                   68 * (2.0268 + tanh((((1.3539 + 0.96818) + 2.295) + 1.3539) * ...
#                                   ((x₁ + -0.18953) + x₁)))))) + (gauss((x₁ * x₁) * (x₀ * 1.5186)...
#                                   ) * 1.186)) + tanh(x₁)) + -0.039891)
# 60          1.787e-01  7.153e-07  y = (((((exp((x₀ * 0.99397) * ((x₀ + (0.40396 * x₁)) + -0.0607...
#                                   11)) + gauss(x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.02...
#                                   68 * (2.0268 + tanh((((1.3539 + 0.96818) + 2.295) + 1.3539) * ...
#                                   ((x₁ + -0.18953) + x₁)))))) + (gauss((x₁ * x₁) * (x₀ * 1.5186)...
#                                   ) * 1.186)) + tanh(x₁)) + tanh(-0.039891))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.560e+05
# Head worker occupation: 19.1%
# Progress: 2399 / 3000 total iterations (79.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.278e+00  1.594e+01  y = 6.2314
# 3           3.081e+00  3.105e-02  y = (6.0467 + x₁)
# 4           2.998e+00  2.712e-02  y = (exp(1.7609) + x₁)
# 5           2.890e+00  3.656e-02  y = ((x₁ + x₁) + 5.2733)
# 8           2.886e+00  4.990e-04  y = ((3.3793 + tanh(x₁)) + (x₁ + 1.9585))
# 9           2.857e+00  1.004e-02  y = ((exp(1.7609) + x₁) + (tanh(x₀) * -0.54711))
# 10          2.653e+00  7.435e-02  y = (((x₁ + exp(1.7609)) + x₁) + (x₀ * -0.54711))
# 11          2.635e+00  6.542e-03  y = (((x₁ + exp(1.7609)) + tanh(x₁)) + (x₀ * -0.54711))
# 12          1.822e+00  3.691e-01  y = ((exp(x₀) + (gauss(x₀ + 0.33443) * 6.8232)) + exp(x₁))
# 13          1.784e+00  2.127e-02  y = ((exp(x₀) * 1.9235) + (gauss((x₀ * x₀) * -3.0423) * 6.2685...
#                                   ))
# 14          1.655e+00  7.459e-02  y = ((exp(x₀ * x₀) + (gauss(x₀ + 0.36301) * 6.3884)) + exp(x₁)...
#                                   )
# 15          9.268e-01  5.801e-01  y = ((exp(x₀) * 1.9235) + (gauss(x₁ + ((x₀ * x₀) * -3.0423)) *...
#                                    6.2685))
# 17          6.033e-01  2.147e-01  y = ((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9088)) * 6.10...
#                                   43)) + 2.1254)
# 18          5.443e-01  1.029e-01  y = ((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.765)) * 6.486...
#                                   7)) + exp(x₁))
# 19          4.142e-01  2.730e-01  y = (((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9299)) * 6.0...
#                                   279)) + x₁) + 1.6786)
# 21          3.952e-01  2.357e-02  y = (((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9299)) * (5....
#                                   4848 + x₁))) + 1.6787) + x₁)
# 22          3.793e-01  4.094e-02  y = ((((exp(x₀ * x₀) + x₁) + (gauss(x₁ + ((x₀ * x₀) * -2.9241)...
#                                   ) * 6.0467)) + 1.2536) + tanh(x₁))
# 23          3.655e-01  3.699e-02  y = ((exp(x₀ * x₀) + (((gauss(x₁ + ((x₀ * x₀) * -2.9299)) * 6....
#                                   0467) + tanh(x₁)) + tanh(x₁))) + 1.333)
# 24          3.497e-01  4.429e-02  y = (((exp(x₀ * x₀) + x₁) + (gauss(x₁ + ((x₀ * x₀) * -2.9241))...
#                                    * 6.0467)) + (0.66743 + tanh(6.0467 * x₁)))
# 25          3.365e-01  3.842e-02  y = (((exp(x₀ * x₀) + x₁) + (gauss(x₁ + ((x₀ * x₀) * -2.9241))...
#                                    * 6.0467)) + (gauss(0.48572) + tanh(6.0467 * x₁)))
# 27          3.214e-01  2.294e-02  y = (((((exp(x₀ * x₀) + (gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5...
#                                   .4848)) + 0.42541) + tanh(5.4848 * x₁)) + x₁) + gauss(x₀))
# 28          3.125e-01  2.808e-02  y = ((exp(x₀ * x₀) + (((gauss(x₁ + ((x₀ * x₀) * -2.9241)) * 6....
#                                   0467) + tanh(x₁ * 6.0467)) + tanh(x₁))) + tanh(x₁ * 6.0467))
# 29          3.103e-01  7.210e-03  y = (((exp(x₀ * x₀) + ((gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5....
#                                   4848) + (x₁ + 0.52007))) + tanh((5.4848 * x₁) + -0.42909)) + g...
#                                   auss(x₀))
# 30          2.986e-01  3.832e-02  y = (((exp(x₀ * x₀) + ((gauss(x₁ + ((x₀ * x₀) * -2.9541)) * 5....
#                                   4848) + tanh(x₁ + x₁))) + (tanh(5.4848 * x₁) * 1.3581)) + gaus...
#                                   s(x₀))
# 32          2.891e-01  1.627e-02  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + tanh(x₁))) + 0.49348) + tanh((5.4848 * x...
#                                   ₁) + -0.42909)) + gauss(x₀))
# 33          2.888e-01  9.566e-04  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + tanh(x₁))) + tanh(0.49348)) + tanh((5.48...
#                                   48 * x₁) + -0.42909)) + gauss(x₀))
# 34          2.885e-01  1.158e-03  y = ((((exp(x₀ * (x₀ + (0.058141 * x₀))) + ((gauss(x₁ + ((x₀ *...
#                                    x₀) * -2.9541)) * 5.4848) + tanh(x₁))) + 0.49348) + tanh((5.4...
#                                   848 * x₁) + -0.42909)) + gauss(x₀))
# 35          2.595e-01  1.058e-01  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + x₁)) + 0.49348) + tanh((5.4848 * x₁) + -...
#                                   0.45363)) + gauss(x₀ * (x₀ + x₁)))
# 37          2.450e-01  2.875e-02  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + x₁)) + 0.49348) + tanh((5.4848 * x₁) + -...
#                                   0.45363)) + gauss((x₀ * (x₀ + x₁)) * x₀))
# 39          2.411e-01  8.004e-03  y = ((((exp(x₀ * (x₀ + 0.058141)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * (5.4848 + -0.15333)) + x₁)) + 0.49348) + tanh((5.4...
#                                   848 * x₁) + -0.45363)) + gauss((x₀ * (x₀ + x₁)) * x₀))
# 40          2.334e-01  3.261e-02  y = ((((exp(x₀ * (x₀ + 0.092003)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + tanh(x₁))) + 0.49348) + tanh(((5.4848 * ...
#                                   x₁) + -0.85803) + x₁)) + gauss((x₀ * x₀) * (x₀ + x₁)))
# 42          2.253e-01  1.772e-02  y = ((((exp(x₀ * (x₀ + 0.092003)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + tanh(x₁))) + 0.49348) + tanh(((5.4848 * ...
#                                   x₁) + -0.85803) + x₁)) + gauss((x₀ * x₀) * ((x₀ * x₀) + x₁)))
# 43          2.226e-01  1.209e-02  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh((2.0268 + 2.0268) * ...
#                                   ((x₁ + x₁) + -0.12275)))))) + gauss(x₁ * x₀)) + gauss(x₀)) + t...
#                                   anh(x₁))
# 44          2.217e-01  3.610e-03  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh(2.0268 * (x₁ + x₁)))...
#                                   ))) + gauss(x₁ * ((x₀ + x₀) * x₁))) + gauss(x₀ * x₀)) + x₁)
# 45          2.174e-01  1.965e-02  y = ((((exp(x₀ * (x₀ + (0.33406 * x₁))) + (gauss(x₁ + ((x₀ * x...
#                                   ₀) * -2.8683)) * (2.0268 * (2.0268 + tanh((2.0268 * (x₁ + (x₁ ...
#                                   + x₁))) + -0.50064))))) + gauss(x₀ * x₁)) + gauss(x₀ * x₀)) + ...
#                                   tanh(x₁))
# 46          2.161e-01  6.371e-03  y = ((((exp(x₀ * (x₀ + 0.092003)) + ((gauss(x₁ + ((x₀ * x₀) * ...
#                                   -2.9541)) * 5.4848) + tanh(x₁))) + 0.49348) + tanh(((5.4848 * ...
#                                   x₁) + -0.85803) + x₁)) + gauss((x₀ * x₀) * ((x₀ * x₀) + ((x₁ +...
#                                    x₁) * x₁))))
# 47          2.070e-01  4.261e-02  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((2.295 + 2.295) * ((x₁ + -0.18953) + x₁)))))) + gauss((...
#                                   x₁ * x₁) * x₀)) + tanh(x₁))
# 48          1.956e-01  5.679e-02  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((2.295 + 2.295) * ((x₁ + -0.18953) + x₁)))))) + gauss((...
#                                   x₁ * x₁) * (x₀ * 1.5186))) + x₁)
# 49          1.951e-01  2.676e-03  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((2.295 + 2.295) * ((x₁ + -0.18953) + x₁)))))) + gauss((...
#                                   x₁ * x₁) * (x₀ * 1.5186))) + tanh(x₁))
# 50          1.926e-01  1.267e-02  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh(((2.295 + 1.7929) + 1.3539) * ((x₁ + -0.18953) + x₁))))...
#                                   )) + gauss((x₁ * x₁) * (x₀ * 1.5186))) + x₁)
# 51          1.832e-01  5.014e-02  y = ((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss(...
#                                   x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268 ...
#                                   + tanh((2.295 + 2.0268) * ((x₁ + -0.18953) + x₁)))))) + gauss(...
#                                   ((x₁ + x₁) * x₁) * x₀)) + tanh(x₁ + x₁))
# 53          1.798e-01  9.392e-03  y = (((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss...
#                                   (x₀)) + -0.074584) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0...
#                                   268 * (2.0268 + tanh((2.295 + 2.0268) * ((x₁ + -0.18953) + x₁)...
#                                   ))))) + gauss(((x₁ + x₁) * x₁) * x₀)) + tanh(x₁ + x��))
# 55          1.798e-01  1.296e-04  y = (((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss...
#                                   (x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268...
#                                    + tanh(((1.5186 + 0.96818) + 2.295) * ((x₁ + -0.18953) + x₁))...
#                                   )))) + (gauss((x₁ * x₁) * (x₀ * 1.5186)) * 1.186)) + tanh(x₁))...
#                                    + -0.039891)
# 57          1.783e-01  4.033e-03  y = (((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss...
#                                   (x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268...
#                                    + tanh((((1.5186 + 0.96818) + 2.295) + 1.846) * ((x₁ + -0.189...
#                                   53) + x₁)))))) + (gauss((x₁ * x₁) * (x₀ * 1.5186)) * 1.186)) +...
#                                    tanh(x₁)) + -0.039891)
# 60          1.783e-01  5.403e-05  y = (((((exp(x₀ * ((x₀ + (0.40396 * x₁)) + -0.060711)) + gauss...
#                                   (x₀)) + (gauss(x₁ + ((x₀ * x₀) * -2.8683)) * (2.0268 * (2.0268...
#                                    + tanh(((((1.5186 + 0.96818) + x₁) + 2.295) + 1.3539) * ((x₁ ...
#                                   + -0.18953) + x₁)))))) + (gauss((x₁ * x₁) * (x₀ * 1.5186)) * 1...
#                                   .186)) + tanh(x₁)) + tanh(-0.039891))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# Checking if pysr_model_temp.pkl exists...
# Loading model from pysr_model_temp.pkl
# Re-fitting candidate 1/44...
#     -> attempt to decrease NDF for bad fits 1/2...
# Re-fitting candidate 2/44...
#     -> attempt to decrease NDF for bad fits 1/2...
# Re-fitting candidate 3/44...
#     -> attempt to decrease NDF for bad fits 1/2...
# Re-fitting candidate 4/44...
#     -> attempt to decrease NDF for bad fits 1/2...
# Re-fitting candidate 5/44...
#     -> attempt to decrease NDF for bad fits 1/2...
# Re-fitting candidate 6/44...
#     -> attempt to decrease NDF for bad fits 1/2...
# Re-fitting candidate 7/44...
#     -> attempt to decrease NDF for bad fits 1/4...
# Re-fitting candidate 8/44...
#     -> attempt to decrease NDF for bad fits 1/4...
# Re-fitting candidate 9/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 10/44...
#     -> attempt to decrease NDF for bad fits 1/4...
# Re-fitting candidate 11/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 12/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 13/44...
#     -> attempt to decrease NDF for bad fits 1/4...
# Re-fitting candidate 14/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 15/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 16/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 17/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 18/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 19/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 20/44...
#     -> attempt to decrease NDF for bad fits 1/16...
# Re-fitting candidate 21/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 22/44...
#     -> attempt to decrease NDF for bad fits 1/4...
# Re-fitting candidate 23/44...
#     -> attempt to decrease NDF for bad fits 1/16...
# Re-fitting candidate 24/44...
#     -> attempt to decrease NDF for bad fits 1/8...
# Re-fitting candidate 25/44...
#     -> attempt to decrease NDF for bad fits 2/32...
# Re-fitting candidate 26/44...
#     -> attempt to decrease NDF for bad fits 2/32...
# Re-fitting candidate 27/44...
#     -> attempt to decrease NDF for bad fits 4/32...
# Re-fitting candidate 28/44...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 29/44...
#     -> attempt to decrease NDF for bad fits 1/32...
# Re-fitting candidate 30/44...
#     -> attempt to decrease NDF for bad fits 1/64...
# Re-fitting candidate 31/44...
#     -> attempt to decrease NDF for bad fits 1/64...
# Re-fitting candidate 32/44...
#     -> attempt to decrease NDF for bad fits 1/64...
# Re-fitting candidate 33/44...
#     -> attempt to decrease NDF for bad fits 14/64...
# Re-fitting candidate 34/44...
#     -> attempt to decrease NDF for bad fits 4/32...
# Re-fitting candidate 35/44...
#     -> attempt to decrease NDF for bad fits 14/64...
# Re-fitting candidate 36/44...
#     -> attempt to decrease NDF for bad fits 1/64...
# Re-fitting candidate 37/44...
#     -> attempt to decrease NDF for bad fits 46/128...
# Re-fitting candidate 38/44...
#     -> attempt to decrease NDF for bad fits 61/256...
# Re-fitting candidate 39/44...
#     -> attempt to decrease NDF for bad fits 61/256...
# Re-fitting candidate 40/44...
#     -> attempt to decrease NDF for bad fits 61/256...
# Re-fitting candidate 41/44...
#     -> attempt to decrease NDF for bad fits 17/128...
# Re-fitting candidate 42/44...
#     -> attempt to decrease NDF for bad fits 65/256...
# Re-fitting candidate 43/44...
#     -> attempt to decrease NDF for bad fits 65/256...
# Re-fitting candidate 44/44...
#     -> attempt to decrease NDF for bad fits 65/256...
# Plotting candidate functions 44/44 to examples/toy_dataset_3/run_b/candidates.pdf...
# Plotting correlation matrices 44/44 to examples/toy_dataset_3/run_b/candidates_correlation.pdf...
# Plotting goodness-of-fit to examples/toy_dataset_3/run_b/candidates_gof.pdf...
